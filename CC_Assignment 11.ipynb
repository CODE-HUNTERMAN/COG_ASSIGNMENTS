# %% [markdown]
# AMAN
# 102316045

# %% [markdown]
# Ques 1. Design a Cognitive Assistant for Reading Labels of medicine bottle

# %% [markdown]
# ![Screenshot 2025-05-04 003117.png](attachment:b9deaec7-4374-4818-8a62-e06ddde3b918.png)

# %% [markdown]
# ![Screenshot 2025-05-04 003324.png](attachment:cea4949e-e2a5-4188-81b2-37e5d39e9241.png)

# %% [markdown]
# Ques 2.Design an Emotion-aware Cognitive Assistant using Facial Expression Detection

# %% [markdown]
# ![Screenshot 2025-05-04 004438.png](attachment:857a7b91-ef34-4ea2-96f9-a235bb6ad0e0.png)

# %% [markdown]
# ![Screenshot 2025-05-04 004557.png](attachment:5819bfaa-69ce-4b05-9e4e-a0000efe3080.png)
